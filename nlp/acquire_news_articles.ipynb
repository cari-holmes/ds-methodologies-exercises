# %% [markdown]
# 2. News Articles
#
# We will now be scraping text data from inshorts, a website that provides a brief overview of many different topics.
#
# Write a function that scrapes the news articles for the following topics:
#
#     Business
#     Sports
#     Technology
#     Entertainment
#
# The end product of this should be a function named get_news_articles that returns a list of dictionaries, where each dictionary has this shape:
#
# {
#     'title': 'The article title',
#     'content': 'The article content',
#     'category': 'business' # for example
# }
#
# **Hints:**
#
# - Start by inspecting the website in your browser. Figure out which elements will be useful.
# - Start by creating a function that handles a single article and produces a dictionary like the one above.
# - Next create a function that will find all the articles on a single page and call the function you created in the last step for every article on the page.
# - Now create a function that will use the previous two functions to scrape the articles from all the pages that you need, and do any additional processing that needs to be done.
#
# **Bonus: cache the data**
#
# 3. Write your code such that the acquired data is saved locally in some form or fashion. Your functions that retrieve the data should prefer to read the local data instead of having to make all the requests everytime the function is called. Include a boolean flag in the functions to allow the data to be acquired "fresh" from the actual sources (re-writing your local cache).

# %%
import pandas as pd
from requests import get
import os
from bs4 import BeautifulSoup

# %%
def get_articles_from_topic(url):
    headers = {'User-Agent':'Codeup Data Science Student'}
    response = get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    output = []
    articles = soup.select(".news-card")
    
    for article in articles:
        title = article.select("[itemprop='headline']")[0].get_text()
        body = article.select("[itemprop='articleBody']")[0].get_text()
        author = article.select(".author")[0].get_text()
        publish_date = article.select(".time")[0].get_text()
        category = response.url.split("/")[-1]
        
        article_data = {'title': title,
                        'body': body,
                        'category': category,
                        'author': author,
                        'publish_date': publish_date
                       }
        output.append(article_data)
        
    return output

# %%
def make_new_request():
    urls = ["https://inshorts.com/en/read/business",
            "https://inshorts.com/en/read/sports",
            "https://inshorts.com/en/read/technology",
            "https://inshorts.com/en/read/entertainment"]
    output = []
    
    for url in urls:
        # use .extend to make flat output list
        output.extend(get_articles_from_topic(url))
    
    df = pd.DataFrame(output)
    df.to_csv('inshorts_news_articles.csv')
    
    return df

# %%
make_new_request()
# Out:
#                     author                                               body  \
# 0   Krishna Veera Vanamali  British cave explorer Vernon Unsworth, who los...
# 1   Krishna Veera Vanamali  After a US jury found that Elon Musk did not d...
# 2                   Dharna  A Lucknow-based customer has filed an FIR agai...
# 3   Krishna Veera Vanamali  Congress leader Shashi Tharoor said he wants a...
# 4   Krishna Veera Vanamali  Finance Minister Nirmala Sitharaman on Saturda...
# 5           Pragya Swastik  The Uttar Pradesh Cabinet on Monday approved Z...
# 6           Pragya Swastik  Former RBI Governor Raghuram Rajan in an artic...
# 7           Pragya Swastik  Price of onion has shot up to ₹200 per kg in B...
# 8   Krishna Veera Vanamali  A panel set up to increase GST collections is ...
# 9           Pragya Swastik  Tata Sons Chairman Emeritus Ratan Tata in an i...
# 10          Pragya Swastik  Walmart has apologised for several adult-theme...
# 11  Krishna Veera Vanamali  Ex-RBI Governor Raghuram Rajan has said India ...
# 12          Pragya Swastik  Mahindra Group Chairman Anand Mahindra on Mond...
# 13                  Dharna  After cutting its output for nine consecutive ...
# 14         Sakshita Khosla  Finance Minister Nirmala Sitharaman said on Sa...
# 15           Anushka Dixit  Yes Bank is reportedly planning to reject an o...
# 16           Anushka Dixit  Proceeds from Saudi Aramco's IPO have risen to...
# 17           Anushka Dixit  Paul Volcker, the former Federal Reserve Chair...
# 18                  Dharna  The SBI has announced a reduction in its one-y...
# 19           Anushka Dixit  People will now be able to purchase seized liq...
# 26  People, my father is not Courtney Walsh: West ...
# 27  If we field so poorly, no amount of runs will ...
# 28  Two pink-ball Tests in a series is too much: B...
# 29  Don't have magic wand to make everything right...
# ..                                                ...
# 69  US charges Russian 'Evil Corp' hackers with $1...
# 70  Reddit bans 61 accounts linked to 'suspected c...
# 71  Tool that helped Amazon's products appear 1st ...
# 72  Facebook makes its 'Crisis Response' tools ava...
# 73  Apple's upcoming iPhone SE 2 may be named 'iPh...
# 74  Which films have been nominated for Best Pictu...
# 75  Rangoli trolls Alia for award-fixing as video ...
# 76  Cricket was in my blood but my cricket career ...
# 77  She sucked it for months: Chrissy to troll ask...
# 78  Kartik Aaryan gets criticised for 'fake abs' i...
# 79  Miss Universe pageant wrongly congratulates Mi...
# 80  'I like sex' line in 'Pati...' wasn't awkward,...
# 81  Glad for your success: SRK to Indonesian actor...
# 82  Rashami was on road, had zero balance in accou...
# 83  People felt I looked like a girl: Saif on the ...
# 84  Sushmita Sen announces her return to films aft...
# 85  Don't attach ancestors' legacy to film: Randee...
# 86  It's deeply disappointing: Dia Mirza on Hydera...
# 87  Won't be in TV show again without creative rol...
# 88  I'm not a political person, don't believe in '...
# 89  Salman, Katrina perform at B'desh Premier Leag...
# 90  Deepika Padukone, Sara Ali Khan attend Star Sc...
# 91  MS Dhoni to produce TV show on army officers: ...
# 92  Overjoyed as 'choti behen' Lata's health is be...
# 93  We just made bad films: Shah Rukh Khan on his ...
# 94  Any major life change is painful: Dia on her s...
# 95  Thought of trying something else when my films...
# 96  'Harry Potter' role didn't satisfy me: Actress...
# 97  We shouldn't be allowed to take life: Waheeda ...
# 98  Ranveer, Alia win Best Actor, Best Actress at ...
#
# [99 rows x 5 columns]

# %%
def get_news_articles():
    filename = 'inshorts_news_articles.csv'
    if os.path.exists(filename):
        return pd.read_csv(filename)
    else:
        return make_new_request()

# %%
df = get_news_articles()

# %%
df.head()
# Out:
#    Unnamed: 0                  author  \
# 0           0  Krishna Veera Vanamali
# 1           1  Krishna Veera Vanamali
# 2           2                  Dharna
# 3           3  Krishna Veera Vanamali
# 4           4  Krishna Veera Vanamali
#
#                                                 body  category publish_date  \
# 0  British cave explorer Vernon Unsworth, who los...  business     09:01 pm
# 1  After a US jury found that Elon Musk did not d...  business     10:04 pm
# 2  A Lucknow-based customer has filed an FIR agai...  business     01:47 pm
# 3  Congress leader Shashi Tharoor said he wants a...  business     07:00 am
# 4  Finance Minister Nirmala Sitharaman on Saturda...  business     06:06 pm
#
#                                                title
# 0  I'll take it on the chin: Cave explorer after ...
# 1  My faith in humanity is restored: Musk after w...
# 2  FIR filed against Club Factory in Lucknow for ...
# 3  I want a 'New India' where Bajaj can speak fea...
# 4  Sitharaman hints at personal income tax rate c...

# %%
df.category.unique()
# Out:
# array(['business', 'sports', 'technology', 'entertainment'], dtype=object)
