# %% [markdown]
# Take the work we did in the lessons further:
#
#     - What other types of models (i.e. different classifcation algorithms) could you use?
#         - Logistic Regression, Decision Tree, Random Forest, etc
#     - How do the models prepare when trained on term frequency data alone, instead of TF-IDF values?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pd

import prepare

# %%
df = prepare.prepare_article_data()

# %%
df.head()
# Out:
#    Unnamed: 0                  author  category publish_date  \
# 0           0  Krishna Veera Vanamali  business     09:01 pm
# 1           1  Krishna Veera Vanamali  business     10:04 pm
# 2           2                  Dharna  business     01:47 pm
# 3           3  Krishna Veera Vanamali  business     07:00 am
# 4           4  Krishna Veera Vanamali  business     06:06 pm
#
#                                                title  \
# 0  I'll take it on the chin: Cave explorer after ...
# 1  My faith in humanity is restored: Musk after w...
# 2  FIR filed against Club Factory in Lucknow for ...
# 3  I want a 'New India' where Bajaj can speak fea...
# 4  Sitharaman hints at personal income tax rate c...
#
#                                             original  \
# 0  British cave explorer Vernon Unsworth, who los...
# 1  After a US jury found that Elon Musk did not d...
# 2  A Lucknow-based customer has filed an FIR agai...
# 3  Congress leader Shashi Tharoor said he wants a...
# ...

# %%
df.drop(columns=('Unnamed: 0'), inplace=True)

# %%
df.category.unique()
# Out:
# array(['business', 'sports', 'technology', 'entertainment'], dtype=object)

# %%
df.head()
# Out:
#                    author  category publish_date  \
# 0  Krishna Veera Vanamali  business     09:01 pm
# 1  Krishna Veera Vanamali  business     10:04 pm
# 2                  Dharna  business     01:47 pm
# 3  Krishna Veera Vanamali  business     07:00 am
# 4  Krishna Veera Vanamali  business     06:06 pm
#
#                                                title  \
# 0  I'll take it on the chin: Cave explorer after ...
# 1  My faith in humanity is restored: Musk after w...
# 2  FIR filed against Club Factory in Lucknow for ...
# 3  I want a 'New India' where Bajaj can speak fea...
# 4  Sitharaman hints at personal income tax rate c...
#
#                                             original  \
# 0  British cave explorer Vernon Unsworth, who los...
# 1  After a US jury found that Elon Musk did not d...
# 2  A Lucknow-based customer has filed an FIR agai...
# 3  Congress leader Shashi Tharoor said he wants a...
# 4  Finance Minister Nirmala Sitharaman on Saturda...
#
# ...

# %%
# def prep_article(df):
#     df = df.assign('original', df.title)
#     df = df.assign('normalized', df.original.apply(basic_clean()))
#     df = df.assign('stemmed',df.original.apply(stem))
#     df = df.assign('lemmantized',df.original.apply(lemmentize))
#     df = df.assign('cleaned',df.original.apply(remove_stopwords))
#     return df
